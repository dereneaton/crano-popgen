# %% [markdown]
# #Cranolopha project
# # Notebook 2: Phylogenetic analysis
# #### D. Eaton, S-Q. Huang & R. Ree
# #### contact: deren.eaton@yale.edu
# --------------------------

# %%
## load scientific computing libraries
import numpy as np               ## v.
import pandas as pd              ## v.

## plotting libraries
import matplotlib.pyplot as plt  ## v.1.3.1
import seaborn as sns            ## v.

## embed plots
# %matplotlib inline

# %%
# %%bash
# ## create directories for analysis
# mkdir -p analysis_raxml/

# %% [markdown]
# -----------------
#
# # RAxML tree inference

# %%
# %%bash
# raxmlHPC-PTHREADS-AVX -f a \
#                       -p 12345 \
#                       -s analysis_pyrad/outfiles/c90d6m40p30.phy \
#                       -x 12345 -N 100 \
#                       -m GTRGAMMA \
#                       -n c90d6m40p30 \
#                       -w /home/deren/Documents/CRANO/analysis_raxml/ \
#                       -o 33286 \
#                       -T 15
# Out:
# Warning, you specified a working directory via "-w"
# Keep in mind that RAxML only accepts absolute path names, not realtive ones!
#
# This is the RAxML Master Pthread
#
# This is RAxML Worker Pthread Number: 4
#
# This is RAxML Worker Pthread Number: 5
#
# This is RAxML Worker Pthread Number: 3
#
# This is RAxML Worker Pthread Number: 1
#
# This is RAxML Worker Pthread Number: 2
#
# This is RAxML Worker Pthread Number: 6
#
# This is RAxML Worker Pthread Number: 7
#
# This is RAxML Worker Pthread Number: 8
#
# This is RAxML Worker Pthread Number: 9
#
# This is RAxML Worker Pthread Number: 10
#
# This is RAxML Worker Pthread Number: 11
#
# This is RAxML Worker Pthread Number: 12
#
# This is RAxML Worker Pthread Number: 13
#
# This is RAxML Worker Pthread Number: 14
#
#
# This is RAxML version 8.0.16 released by Alexandros Stamatakis on March 21 2014.
#
# With greatly appreciated code contributions by:
# Andre Aberer      (HITS)
# Simon Berger      (HITS)
# Alexey Kozlov     (HITS)
# ...

# %%
#### plot some tree here with R
# %load_ext rmagic

# %%
# %%R -w 400 -h 1200 -u px
# library(ape)
# tre <- read.tree("analysis_raxml/RAxML_bipartitions.c90d6m40p30")
# rtre = root(tre,c("41112","33286","39969","30106"))
# plot(ladderize(rtre),cex=0.8)
# nodelabels(rtre$node.label)
